# %%
import nbimporter

from step0_dataset import dataset_builtin
from step1_calories_calculator import how_many_calories_do_you_need
from step2_calories_origin import where_do_you_get_the_calories_from, example
# Out:
# Importing Jupyter notebook from step0_dataset.ipynb
# Importing Jupyter notebook from step1_calories_calculator.ipynb
# Importing Jupyter notebook from step2_calories_origin.ipynb

# %%
dataset=dataset_builtin()
My_name, dataset,Age,Gender,Activity = how_many_calories_do_you_need(
#####################################################################
#          CHANGE INPUTS FOLLOWING THE INSTRUCTIONS BELOW           #
#####################################################################    
                 'Grazia', # enter your name
                 dataset, # don't change this
                 Age=59, # enter your age
                 Activity='Sedentary', # are you'Sedentary','Low Active' or 'Active'?
                 Gender='Female', # enter your gender
                 Graph=True) # you don't like graphs? Change True to False.
# Out:
# Hello Grazia, are you ready to become healthier? Welcome to the session. If you are a Female, 59 years old and Sedentary,you need to eat 1650 kcal per day. Easy right!? look at the graph below. If you cant see it, set "Graph"=True. If you dont like graphs, just set "Graph"=False.
# Dear Grazia, do you want to know how to get those kcal? Follow me.

# %%
where_do_you_get_the_calories_from(Age,Gender); example()
# Out:
# This are the daily servings per category.
# Fruit Female                    7.0
# Vegetables Female               7.0
# Grains Female                   6.0
# Milk and alternatives Female    3.0
# Meat and alternatives Female    3.0
# Name: 51-70 years, dtype: float64
#
# What is a serving anyways!? See the examples below.
#
# **Fruit and vegetables**: 1 piece of fruit, half a cup of fruit juice,
# 	half a cup of canned or frozen fruit or vegetables, 1 cup of leafy raw
# 	vegetables or salad.
# **Grains**: Half a bagel, 1 slice of bread, half a tortilla, half a pitta,
# 	half a cup of cooked couscous, rice or pasta, one ounce of cold cereal,
# 	three-quarters of a cup of hot cereal.
# **Milk and alternatives**: 1 cup milk, 1 cup of soy drink, three-quarters of
# 	a cup of yogurt, 1 and a half ounces of cheese.
# **Meat and alternatives**: 2 and a half ounces of cooked fish, lean meat,
# 	poultry or lean meat, 2 eggs, 2 tablespoons of peanut butter.
